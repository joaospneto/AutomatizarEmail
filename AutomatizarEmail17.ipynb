# %% [markdown]
# <a href="https://colab.research.google.com/github/joaospneto/AutomatizarEmail/blob/main/AutomatizarEmail17.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
vendas_df = pd.read_excel('/content/Registro - Vendas.xlsx')
faturamento_total = vendas_df['Ticket da Venda'].sum()
print(faturamento_total)
vendas_df
# Out:
# 155214.4
#      Pedido       Data Cod Item  Ticket da Venda
# 0     19468 2022-06-02  MEX1978           102.04
# 1     10767 2022-06-03  PIZ1555           371.82
# 2     12838 2022-06-03  PIZ1140           434.76
# 3     17023 2022-06-03  ARA1396           542.50
# 4     20535 2022-06-02  ARA1799            94.00
# ..      ...        ...      ...              ...
# 272   58385 2022-06-29  MEX1626           841.56
# 273   58486 2022-06-28  PIZ1518            71.02
# 274   60477 2022-06-26  ARA1678           375.26
# 275   62113 2022-06-25  PIZ1072           235.00
# 276   70822 2022-06-25  ARA1396           132.50
#
# [277 rows x 4 columns]

# %%
lista_df = pd.read_excel('/content/Lista Emails.xlsx')
lista_df
# Out:
#      Nome                  E-mail
# 0  Wisley  wisleykillat@gmail.com
# 1   João   joaopsilvant@gmail.com
# 2     Ana    joapnetocd@gmail.com

# %%
import smtplib
from email.mime.multipart import MIMEMultipart
from email.mime.text import MIMEText

# Configurações do servidor SMTP do Gmail
smtp_server = "smtp.gmail.com"
smtp_port = 587
login = "joaote@gmail.com"
senha = "743884"

# Configuração do email
for i, email in enumerate(lista_df['E-mail']):
    nome = lista_df.loc[i, 'Nome'].strip()

    # Criar a mensagem
    msg = MIMEMultipart()
    msg['From'] = login
    msg['To'] = email
    msg['Subject'] = "Faturamento do mês de Agosto"

    # Corpo do email em HTML
    body = (
        f"Oi {nome},<br><br>"
        "Tudo bem? Estou te enviando um relatório do mês de Agosto!<br>"
        "Segue em anexo o registro das vendas!<br><br>"
        f"O faturamento do mês foi {faturamento_total}."
    )
    msg.attach(MIMEText(body, 'html'))


    try:
        server = smtplib.SMTP(smtp_server, smtp_port)
        server.starttls()
        server.login(login, senha)
        server.send_message(msg)
        server.quit()
        print(f"Email enviado com sucesso para: {email}")
    except Exception as e:
        print(f"Erro ao enviar email para {email}: {str(e)}")
# Out:
# Erro ao enviar email para wisleykillat@gmail.com: (535, b'5.7.8 Username and Password not accepted. For more information, go to\n5.7.8  https://support.google.com/mail/?p=BadCredentials d2e1a72fcca58-7127af16635sm7481932b3a.147 - gsmtp')
# Erro ao enviar email para joaopsilvant@gmail.com: (535, b'5.7.8 Username and Password not accepted. For more information, go to\n5.7.8  https://support.google.com/mail/?p=BadCredentials d2e1a72fcca58-7127af1f2cesm7244328b3a.181 - gsmtp')
# Erro ao enviar email para joapnetocd@gmail.com: (535, b'5.7.8 Username and Password not accepted. For more information, go to\n5.7.8  https://support.google.com/mail/?p=BadCredentials d9443c01a7336-201f03b15bdsm68721895ad.303 - gsmtp')
